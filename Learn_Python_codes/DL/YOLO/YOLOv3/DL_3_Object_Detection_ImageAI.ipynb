# %%
from imageai.Detection import ObjectDetection, VideoObjectDetection
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model_path = "/content/drive/MyDrive/model_path"
images_path = "https://github.com/fazelelham32/Learn_PythonCodes/tree/main/Learn_Python_codes/Image_processing/Images"
video_path = "https://github.com/fazelelham32/Learn_PythonCodes/tree/main/Learn_Python_codes/Image_processing/Videos"

# %%
detector = ObjectDetection()

# %%
detector.setModelTypeAsYOLOv3()

# %%
import urllib.request
import os

# آدرسی که می‌خواهید فایل در آن ذخیره شود
save_path = "/content/drive/MyDrive/model_path/yolov3.pt"

# ایجاد پوشه در صورت عدم وجود
os.makedirs(os.path.dirname(save_path), exist_ok=True)

# لینک دانلود مطمئن از مخزن رسمی ImageAI
url = "https://github.com/OlafenwaMoses/ImageAI/releases/download/3.0.0-pretrained/yolov3.pt"

print("در حال دانلود فایل مدل...")
urllib.request.urlretrieve(url, save_path)
print("دانلود با موفقیت انجام شد! آدرس فایل:", save_path)
# Out:
# در حال دانلود فایل مدل...
# دانلود با موفقیت انجام شد! آدرس فایل: /content/drive/MyDrive/model_path/yolov3.pt

# %%
from imageai.Detection import ObjectDetection

detector = ObjectDetection()
detector.setModelTypeAsYOLOv3()

# آدرس دقیق فایل دانلود شده
detector.setModelPath("/content/drive/MyDrive/model_path/yolov3.pt")
detector.loadModel()

print("مدل با موفقیت لود شد!")
# Out:
# مدل با موفقیت لود شد!

# %%
import os
from imageai.Detection import ObjectDetection

# ۱. ایجاد شیء تشخیص اشیاء و تعیین نوع مدل
detector = ObjectDetection()
detector.setModelTypeAsYOLOv3()

# ۲. آدرس پوشه‌ای که فایل مدل در آن قرار دارد
model_path = "/content/drive/MyDrive/model_path"

# ۳. ترکیب آدرس پوشه با نام فایل جدید (yolov3.pt)
file_path = os.path.join(model_path, "yolov3.pt")

# ۴. ست کردن آدرس و بارگذاری مدل
detector.setModelPath(file_path)
detector.loadModel()

print("مدل با موفقیت بارگذاری شد!")
# Out:
# مدل با موفقیت بارگذاری شد!

# %%
detector.setModelPath(os.path.join(model_path , "yolov3.pt"))

# %%
custom_detector = detector.CustomObjects(car=True)

# %%
import os

# استفاده از detectObjectsFromImage به جای detectCustomObjectsFromImage
custom_detection = detector.detectObjectsFromImage(
    custom_objects=custom_detector,
    input_image=os.path.join(images_path, "04_tehran.png"),
    output_image_path=os.path.join(images_path, "04_tehran_customdetected.jpg"),
    minimum_percentage_probability=80
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7450/3227874436.py in <cell line: 0>()
#       2
#       3 # استفاده از detectObjectsFromImage به جای detectCustomObjectsFromImage
# ----> 4 custom_detection = detector.detectObjectsFromImage(
#       5     custom_objects=custom_detector,
#       6     input_image=os.path.join(images_path, "04_tehran.png"),
#
# /usr/local/lib/python3.12/dist-packages/imageai/Detection/__init__.py in detectObjectsFromImage(self, input_image, output_image_path, output_type, extract_detected_objects, minimum_percentage_probability, display_percentage_probability, display_object_name, display_box, custom_objects)
#     336
#     337         if self.__model_type == "yolov3" or self.__model_type == "tiny-yolov3":
# --> 338             fnames, original_imgs, input_dims, imgs = self.__load_image_yolo(input_image)
#     339
#     340             with torch.no_grad():
#
# /usr/local/lib/python3.12/dist-packages/imageai/Detection/__init__.py in __load_image_yolo(self, input_image)
#      89                     img = cv2.imread(input_image)
#      90             else:
# ---> 91                 raise ValueError(f"image path '{input_image}' is not found or a valid file")
#      92         elif type(input_image) == np.ndarray:
#      93             img = input_image
#
# ValueError: image path 'https://github.com/fazelelham32/Learn_PythonCodes/tree/main/Learn_Python_codes/Image_processing/Images/04_tehran.png' is not found or a valid file

# %%
import os

# آدرس پوشه تصاویر
images_path = "/content/drive/MyDrive/images"

# جهت اطمینان از وجود فایل ورودی
input_file = os.path.join(images_path, "04_tehran.png")
print("آیا تصویر ورودی وجود دارد؟", os.path.exists(input_file))
# Out:
# آیا تصویر ورودی وجود دارد؟ False

# %%
# ساخت فیلتر سفارشی (مثلاً فقط تشخیص خودرو و فرد)
custom_detector = detector.CustomObjects(car=True, person=True)

# %%
import os
from imageai.Detection import ObjectDetection

# ۱. راه‌اندازی و بارگذاری مدل
detector = ObjectDetection()
detector.setModelTypeAsYOLOv3()
detector.setModelPath("/content/drive/MyDrive/model_path/yolov3.pt")
detector.loadModel()

# ۲. مشخص کردن مسیر تصاویر
images_path = "/content/drive/MyDrive/images"

# ۳. تنظیم فیلتر سفارشی (مثلاً فقط خودرو)
custom_detector = detector.CustomObjects(car=True)

# ۴. اجرای تشخیص روی تصویر
custom_detection = detector.detectObjectsFromImage(
    custom_objects=custom_detector,
    input_image=os.path.join(images_path, "04_tehran.png"),
    output_image_path=os.path.join(images_path, "04_tehran_customdetected.jpg"),
    minimum_percentage_probability=80
)

# ۵. چاپ نتایج
for obj in custom_detection:
    print(obj["name"], " : ", obj["percentage_probability"], "%")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7450/2999535281.py in <cell line: 0>()
#      15
#      16 # ۴. اجرای تشخیص روی تصویر
# ---> 17 custom_detection = detector.detectObjectsFromImage(
#      18     custom_objects=custom_detector,
#      19     input_image=os.path.join(images_path, "04_tehran.png"),
#
# /usr/local/lib/python3.12/dist-packages/imageai/Detection/__init__.py in detectObjectsFromImage(self, input_image, output_image_path, output_type, extract_detected_objects, minimum_percentage_probability, display_percentage_probability, display_object_name, display_box, custom_objects)
#     336
#     337         if self.__model_type == "yolov3" or self.__model_type == "tiny-yolov3":
# --> 338             fnames, original_imgs, input_dims, imgs = self.__load_image_yolo(input_image)
#     339
#     340             with torch.no_grad():
#
# /usr/local/lib/python3.12/dist-packages/imageai/Detection/__init__.py in __load_image_yolo(self, input_image)
#      89                     img = cv2.imread(input_image)
#      90             else:
# ---> 91                 raise ValueError(f"image path '{input_image}' is not found or a valid file")
#      92         elif type(input_image) == np.ndarray:
#      93             img = input_image
#
# ValueError: image path '/content/drive/MyDrive/images/04_tehran.png' is not found or a valid file

# %%
custom_detection
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7450/1179179398.py in <cell line: 0>()
# ----> 1 custom_detection
#
# NameError: name 'custom_detection' is not defined

# %%
# Video object detection

# %%
video_detector = VideoObjectDetection()

# %%
video_detector.setModelTypeAsYOLOv3()

# %%
video_detector.setModelPath(os.path.join(model_path , "yolov3.h5"))
video_detector.loadModel(detection_speed="fast")

# %%
vid_detection = video_detector.detectObjectsFromVideo(input_file_path= os.path.join(video_path, "street_camera.mp4"), output_file_path= os.path.join(video_path, "street_camera_fastest_det"), frames_per_second=20, log_progress=True)

# %%
video_detector.setModelPath(os.path.join(model_path , "yolov3.h5"))
video_detector.loadModel()
vid_detection = video_detector.detectObjectsFromVideo(input_file_path= os.path.join(video_path, "street_camera.mp4"), output_file_path= os.path.join(video_path, "street_camera_det"), frames_per_second=20, log_progress=True)

# %%
video_detector.setModelPath(os.path.join(model_path , "yolov3.h5"))
video_detector.loadModel(detection_speed="fast")
vid_detection = video_detector.detectObjectsFromVideo(input_file_path= os.path.join(video_path, "street_camera.mp4"), output_file_path= os.path.join(video_path, "street_camera_fast_det"), frames_per_second=20, log_progress=True)

# %%
video_detector.setModelPath(os.path.join(model_path , "yolov3.h5"))
video_detector.loadModel(detection_speed="faster")
vid_detection = video_detector.detectObjectsFromVideo(input_file_path= os.path.join(video_path, "street_camera.mp4"), output_file_path= os.path.join(video_path, "street_camera_faster_det"), frames_per_second=20, log_progress=True)

# %%
video_detector.setModelPath(os.path.join(model_path , "yolov3.h5"))
video_detector.loadModel(detection_speed="flash")
vid_detection = video_detector.detectObjectsFromVideo(input_file_path= os.path.join(video_path, "street_camera.mp4"), output_file_path= os.path.join(video_path, "street_camera_flash_det"), frames_per_second=20, log_progress=True)

# %%
# Using the Webcam
import cv2 as cv

# %%
camera = cv.VideoCapture(0)

# %%
webcam_detector = VideoObjectDetection()
webcam_detector.setModelTypeAsYOLOv3()
webcam_detector.setModelPath(os.path.join(model_path , "yolov3.h5"))
webcam_detector.loadModel()

# %%
vid_detection = video_detector.detectObjectsFromVideo(camera_input=camera, output_file_path = os.path.join(video_path, "camera_detected_video"),
                frames_per_second = 20, log_progress=True)
